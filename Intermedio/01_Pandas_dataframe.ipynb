# %%
import pandas as pd

#Creazioen della lista 
studenti = {
    'nomi': ['Massa', 'Antonella', 'Luigi', 'Eduardo', 'Matteo', 'Stefano', 'Lucia', 'Annaritantonia', 'Paolo', "Gesualdo"],
    'voti': [10, 8, 9, 7, 10, 6, 5, 4, 10, 8]
}

# Creazione del DataFrame(Foglio excel, Tabella, Entità)
df = pd.DataFrame(studenti)

print(df) # stampa il DataFrame
# Out:
#              nomi  voti
# 0           Massa    10
# 1       Antonella     8
# 2           Luigi     9
# 3         Eduardo     7
# 4          Matteo    10
# 5         Stefano     6
# 6           Lucia     5
# 7  Annaritantonia     4
# 8           Paolo    10
# 9        Gesualdo     8

# %% [markdown]
# # Filtrare dati
# - studenti promossi

# %%
promossi = df[df['voti'] >= 9]
print("\nPromossi:\n", promossi)
# Out:
# Promossi:
#       nomi  voti
# 0   Massa    10
# 2   Luigi     9
# 4  Matteo    10
# 8   Paolo    10

# %% [markdown]
# <h3><i>Calcolare la media</i><h3>

# %%
media_voti = df['voti'].mean()
print("\nMedia dei voti:", media_voti)
# Out:
# Media dei voti: 7.7

# %% [markdown]
# La funzione (info() restituisce del Dataframe ()

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
print (df.describe())
# Out:
#             voti
# count  10.000000
# mean    7.700000
# std     2.162817
# min     4.000000
# 25%     6.250000
# 50%     8.000000
# 75%     9.750000
# max    10.000000

# %% [markdown]
# <h3> Salvataggio in un file csv</h3>

# %%
# creazione del DataFrame (dipendenti) con un dizionario di liste ==> dataset, entità, foglio excel, tabella
import pandas as pd
import matplotlib.pyplot as plt

dipendenti = {
    "nome": ["Mario", "Rudy", "Marco", "Luca", "Giovanni", "Francesco", "Giulia", "Elena", "Federica", "Alessandro"],
    "cognome": ["Ricci", "Botosso", "Secci", "Bianchi", "Neri", "Rossi", "Verdi", "Gialli", "Blu", "Rosa"],
    "email": ["mario.ricci@example.info", None, "marco.secci@example.com", None, "giovanni.neri@example.com", "francesco.rossi@example.ue", "giulia.verdi@example.com", "elena.gialli@example.it", "federica.blu@example.com", "alessandro.rosa@example.info"],
    "eta": [30, 54, 54, 28, 35, 42, 28, 32, 29, 31],
    "citta": ["Milano", "Biella", "San Donà di Piave", "Roma", "Napoli", "Torino", "Firenze", "Bologna", "Genova", "Padova"],
    "stipendio": [2000, 3000, 1500, 2500, 3500, 4000, 2500, 3000, 3500, 4000],
    "ruolo": ["Sviluppatore", "Project Manager", "Analista", "Sviluppatore", "Team Leader", "Project Manager", "Sviluppatore", "Analista", "Team Leader", "Project Manager"],
    "data_assunzione": ["2015-01-15", "2010-06-30", "2018-09-01", "2016-03-20", "2012-11-05", "2008-04-10", "2017-07-25", "2014-02-18", "2013-12-12", "2009-08-01"]
}

df = pd.DataFrame(dipendenti)
df
# Out:
#          nome  cognome                         email  eta              citta  \
# 0       Mario    Ricci      mario.ricci@example.info   30             Milano
# 1        Rudy  Botosso                           NaN   54             Biella
# 2       Marco    Secci       marco.secci@example.com   54  San Donà di Piave
# 3        Luca  Bianchi                           NaN   28               Roma
# 4    Giovanni     Neri     giovanni.neri@example.com   35             Napoli
# 5   Francesco    Rossi    francesco.rossi@example.ue   42             Torino
# 6      Giulia    Verdi      giulia.verdi@example.com   28            Firenze
# 7       Elena   Gialli       elena.gialli@example.it   32            Bologna
# 8    Federica      Blu      federica.blu@example.com   29             Genova
# 9  Alessandro     Rosa  alessandro.rosa@example.info   31             Padova
#
#    stipendio            ruolo data_assunzione
# 0       2000     Sviluppatore      2015-01-15
# 1       3000  Project Manager      2010-06-30
# 2       1500         Analista      2018-09-01
# 3       2500     Sviluppatore      2016-03-20
# 4       3500      Team Leader      2012-11-05
# 5       4000  Project Manager      2008-04-10
# 6       2500     Sviluppatore      2017-07-25
# 7       3000         Analista      2014-02-18
# 8       3500      Team Leader      2013-12-12
# 9       4000  Project Manager      2009-08-01

# %%
# nome del file CSV
# definisce il percorso del csv dove salvare il DataFrame
percorso_file = r'C:\Users\sderu\Documents\Corsi\MAW - Data Analyst + Python\Corso Completo di PYTHON\Intermedio\Data\dipendenti.csv'

# Salvataggio del DataFrame in csv
df.to_csv(percorso_file, index=False)

# %%
# Salvataggio del DataFrame in excel
percorso_file1 = r'C:\Users\sderu\Documents\Corsi\MAW - Data Analyst + Python\Corso Completo di PYTHON\Intermedio\Data\dipendenti.xlsx'
df.to_excel(percorso_file1 , index=False)

# %% [markdown]
# # definisce il percorso del csv dove salvare il dataframe

# %%
percorso_file_excel = r'C:\Users\sderu\Documents\Corsi\MAW - Data Analyst + Python\Corso Completo di PYTHON\Intermedio\Data\dipendenti_01.xlsx'
df.to_excel(percorso_file_excel, index=False)
